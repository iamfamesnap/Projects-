# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 2</b>
#
#
# Thank you for updating your project! :)
#
#
# I've left new comments titled as **Reviewer's comment 2**. Your project has passed code review. Congratulations and good luck! 😊
#
#
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment</b>
#
# Hi! I am a reviewer on this project.
#
# I will be using the standard color marking:
#
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
# Great solutions and ideas that can and should be used in the future are in green comments.
# </div>
#
#
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
# Yellow color indicates what should be optimized. This is not necessary, but it will be great if you make changes to this project.
# </div>
#
#
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
# Issues that need to be corrected to get right results are indicated in red comments. Note that the project cannot be accepted until these issues are resolved.
# </div>
#
# <hr>
#
# **Please, use some color other than those listed to highlight answers to my comments.**
# I would also ask you **not to change, move or delete my comments** so that it would be easier for me to navigate during the next review.
#
# In addition, my comments are defined as headings.
# They can mess up the content, however, they are convenient, since you can immediately go to them. I will remove the headings from my comments in the next review.
#
#
#
# <hr>
#
# <font color='dodgerblue'>**A few words about the project:**</font>  you did a very good job here! There are charts and conclusions, which is great. However, there are a couple of issues that need your attention. Would you take a look at my comments?
#
#
# I will wait for the project for a second review :)
#
#
#
# 📌 Here is a useful SQL [Cheat Sheet](https://www.sqltutorial.org/sql-cheat-sheet/).
#     You can also check out SQL on leetcode: [link](https://leetcode.com/study-plan/sql/).
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
# First things first. The introduction is the initial paragraph that each project, each essay or any article should have. It is important to write an introductory part, because it gives an idea about the content of the project. Please, add a title and some introduction.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Student сomments:</b> Introduction has been added</div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 </h2>
#
# Good!
#
# </div>

# %% [markdown]
# ## Project Introduction
#
# The project aims to analyze passenger preferences and identify key factors influencing ride frequency for Zuber, a new ride-sharing company launching in Chicago. As part of the analysis, we will examine available data to uncover patterns in passenger behavior, assess the impact of external variables such as weather, and compare Zuber’s performance against competitors. A primary focus will be testing the hypothesis that weather conditions significantly affect ride frequency, with the goal of providing actionable insights that can inform business strategies and improve service offerings in the Chicago market.

# %% [markdown]
# ## Step 1: Import the Files

# %%
import pandas as pd 
#load the datasets 


# Load the datasets
taxi_data = pd.read_csv('/datasets/project_sql_result_01.csv')
neighborhood_data = pd.read_csv('/datasets/project_sql_result_04.csv')

(taxi_data)
# Out:
#                        company_name  trips_amount
# 0                         Flash Cab         19558
# 1         Taxi Affiliation Services         11422
# 2                 Medallion Leasing         10367
# 3                        Yellow Cab          9888
# 4   Taxi Affiliation Service Yellow          9299
# ..                              ...           ...
# 59     4053 - 40193 Adwar H. Nikola             7
# 60          2733 - 74600 Benny Jona             7
# 61    5874 - 73628 Sergey Cab Corp.             5
# 62       2241 - 44667 - Felman Corp             3
# 63      3556 - 36214 RC Andrews Cab             2
#
# [64 rows x 2 columns]

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment</h2>
#
#
# You can import modules in one cell and read data in another.
#
# </div>

# %%
(neighborhood_data)
# Out:
#    dropoff_location_name  average_trips
# 0                   Loop   10727.466667
# 1            River North    9523.666667
# 2          Streeterville    6664.666667
# 3              West Loop    5163.666667
# 4                 O'Hare    2546.900000
# ..                   ...            ...
# 89       Mount Greenwood       3.137931
# 90             Hegewisch       3.117647
# 91              Burnside       2.333333
# 92             East Side       1.961538
# 93             Riverdale       1.800000
#
# [94 rows x 2 columns]

# %% [markdown]
# ## Make sure the datatypes are correct

# %%
(taxi_data.dtypes)
# Out:
# company_name    object
# trips_amount     int64
# dtype: object

# %%
(neighborhood_data.dtypes)
# Out:
# dropoff_location_name     object
# average_trips            float64
# dtype: object

# %%
# Ensure correct data types
taxi_data['company_name'] = taxi_data['company_name'].astype(str)
taxi_data['trips_amount'] = taxi_data['trips_amount'].astype(int)

neighborhood_data['dropoff_location_name'] = neighborhood_data['dropoff_location_name'].astype(str)
neighborhood_data['average_trips'] = neighborhood_data['average_trips'].astype(float)

# %%
# Check dataframes for duplicates
print(taxi_data.duplicated().sum())
print(neighborhood_data.duplicated().sum())
# Out:
# 0
# 0

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
# Let's check all the dataframes for the duplicates. Although the file could be prepared by ourselves, we still should check it. Sometimes problems occur when the file is uploading, for instance.
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 </h2>
#
# Well done!
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Student сomments:</b> Duplicates have been checked, and there are no duplicates in the dataframe </div>

# %% [markdown]
# ## Identify the top 10 neighborhoods by drop-offs

# %%
# Sort neighborhoods by average trips (drop-offs) in descending order
top_10_neighborhoods = neighborhood_data.sort_values(by='average_trips', ascending=False).head(10)
print(top_10_neighborhoods[['dropoff_location_name', 'average_trips']])
# Out:
#   dropoff_location_name  average_trips
# 0                  Loop   10727.466667
# 1           River North    9523.666667
# 2         Streeterville    6664.666667
# 3             West Loop    5163.666667
# 4                O'Hare    2546.900000
# 5             Lake View    2420.966667
# 6            Grant Park    2068.533333
# 7         Museum Campus    1510.000000
# 8            Gold Coast    1364.233333
# 9    Sheffield & DePaul    1259.766667

# %% [markdown]
# ## Visualize the Data

# %%
import matplotlib.pyplot as plt

# Graph 1: Top Taxi Companies and Number of Rides
plt.figure(figsize=(20, 12))
plt.barh(taxi_data['company_name'], taxi_data['trips_amount'], color='teal')
plt.xlabel('Number of Rides')
plt.ylabel('Taxi Company')
plt.title('Taxi Companies and Number of Rides (Nov 15-16, 2017)')
plt.gca().invert_yaxis()  # To display the highest value at the top
plt.show()

# Graph 2: Top 10 Neighborhoods by Number of Drop-offs
plt.figure(figsize=(10, 6))
plt.barh(top_10_neighborhoods['dropoff_location_name'], top_10_neighborhoods['average_trips'], color='orange')
plt.xlabel('Average Number of Drop-offs')
plt.ylabel('Neighborhood')
plt.title('Top 10 Neighborhoods by Average Number of Drop-offs (Nov 2017)')
plt.gca().invert_yaxis()  # To display the highest value at the top
plt.show()

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>  Reviewer's comment </h2>
#
#
# - [PEP8](https://peps.python.org/pep-0008/) states that one should always put imports at the top of the file. It's a good practice, since everyone who is going to read the project, can immediately figure out what modules need to be installed. Moreover, imports should be placed in a separate cell.
#
#
#
# - On the first chart, it is enough to show top 10-15 names.
#
# </div>

# %% [markdown]
# ## Visualizations Conclusions
#
# Taxi Companies and the number of rides bar plot shows how the rides were distributed among taxi companies. Some companies had significantly more rides than others indicating that they had either a better service product or a larger market share for this time period.
# The top 10 neighborhood bar plot shows which Chicago neighborhoods had the highest average amount of dropoffs in Nov.2017. This can provide insights into which areas are most frequented by taxis, potentially indicating areas of higher demand, such as business districts, entertainment areas, or neighborhoods with high-density residential buildings.It could also highlight seasonal or event-based trends, such as an increased number of rides around popular events, festivals, or conferences.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment </h2>
#
#
# Good!
# </div>

# %% [markdown]
# ## Testing Hypotheses(Python)

# %% [markdown]
# The null hypothesis: there is no difference in ride durations between rainy and non-rainy Saturdays.
#
# The alternative hypothesis: The average ride duration differs between rainy and non-rainy Saturdays.

# %%
import pandas as pd

# Load the dataset
ride_data = pd.read_csv('/datasets/project_sql_result_07.csv')

# Inspect the first few rows of the data
ride_data.head()
# Out:
#               start_ts weather_conditions  duration_seconds
# 0  2017-11-25 16:00:00               Good            2410.0
# 1  2017-11-25 14:00:00               Good            1920.0
# 2  2017-11-25 12:00:00               Good            1543.0
# 3  2017-11-04 10:00:00               Good            2512.0
# 4  2017-11-11 07:00:00               Good            1440.0

# %%
ride_data.duplicated().sum()
# Out:
# 197

# %%
ride_data_cleaned = ride_data.drop_duplicates(subset=['start_ts', 'duration_seconds'])
(ride_data_cleaned)
# Out:
#                 start_ts weather_conditions  duration_seconds  day_of_week
# 0    2017-11-25 16:00:00               Good            2410.0            5
# 1    2017-11-25 14:00:00               Good            1920.0            5
# 2    2017-11-25 12:00:00               Good            1543.0            5
# 3    2017-11-04 10:00:00               Good            2512.0            5
# 4    2017-11-11 07:00:00               Good            1440.0            5
# ...                  ...                ...               ...          ...
# 1060 2017-11-04 14:00:00               Good            2700.0            5
# 1061 2017-11-18 16:00:00                Bad            2186.0            5
# 1063 2017-11-25 11:00:00               Good               0.0            5
# 1064 2017-11-11 10:00:00               Good            1318.0            5
# 1067 2017-11-04 16:00:00                Bad            2834.0            5
#
# [871 rows x 4 columns]

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
# Are there any duplicates here?
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 </h2>
#
# Very good!
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Student сomments:</b> Duplicates have been checked, and there were duplicates in the dataframe that i chose to remove based on specific columns that should be unique. </div>

# %% [markdown]
# Data Prep

# %%
# Convert the start_ts to datetime format to easily extract the day of the week
ride_data_cleaned['start_ts'] = pd.to_datetime(ride_data_cleaned['start_ts'])

# Extract the day of the week (0 = Monday, 6 = Sunday)
ride_data_cleaned['day_of_week'] = ride_data_cleaned['start_ts'].dt.dayofweek

# Filter data for Saturdays (day_of_week == 5)
saturday_data = ride_data_cleaned[ride_data_cleaned['day_of_week'] == 5]

# Now filter the data into rainy and non-rainy conditions
rainy_saturdays = saturday_data[saturday_data['weather_conditions'] == 'Bad']
non_rainy_saturdays = saturday_data[saturday_data['weather_conditions'] != 'Bad']
(rainy_saturdays)
# Out:
# /tmp/ipykernel_66/3837606172.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ride_data_cleaned['start_ts'] = pd.to_datetime(ride_data_cleaned['start_ts'])
# /tmp/ipykernel_66/3837606172.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ride_data_cleaned['day_of_week'] = ride_data_cleaned['start_ts'].dt.dayofweek
#                 start_ts weather_conditions  duration_seconds  day_of_week
# 6    2017-11-04 16:00:00                Bad            2969.0            5
# ...

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment </h2>
#
#
# You can use `parse_dates` agrument while reading the dataframe. Pandas will try to read the data field. This is a good [article](https://saturncloud.io/blog/how-to-parse-dates-in-different-columns-with-pandas-readcsv/) with the examples.
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment </b>
#
#
# Is everything correct with the conditions?
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 </h2>
#
# Yes, the previous conditions created identical subsets.
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Student сomments:</b> There was an error in my code that i completely overlooked. I had non_rainy_saturdays = saturday_data[saturday_data['weather_conditions'] != 'Good'] when the code should have read
# non_rainy_saturdays = saturday_data[saturday_data['weather_conditions'] != 'Bad'] the error has been fixed.
# </div>

# %%
(non_rainy_saturdays)
# Out:
#                 start_ts weather_conditions  duration_seconds  day_of_week
# 0    2017-11-25 16:00:00               Good            2410.0            5
# 1    2017-11-25 14:00:00               Good            1920.0            5
# 2    2017-11-25 12:00:00               Good            1543.0            5
# 3    2017-11-04 10:00:00               Good            2512.0            5
# 4    2017-11-11 07:00:00               Good            1440.0            5
# ...                  ...                ...               ...          ...
# 1057 2017-11-04 12:00:00               Good            2492.0            5
# 1059 2017-11-11 10:00:00               Good            1303.0            5
# 1060 2017-11-04 14:00:00               Good            2700.0            5
# 1063 2017-11-25 11:00:00               Good               0.0            5
# 1064 2017-11-11 10:00:00               Good            1318.0            5
#
# [723 rows x 4 columns]

# %%
# Calculate basic statistics for the two groups
rainy_saturdays_duration = rainy_saturdays['duration_seconds']
non_rainy_saturdays_duration = non_rainy_saturdays['duration_seconds']

# Get descriptive statistics (mean, std, etc.)
rainy_saturdays_duration.describe(), non_rainy_saturdays_duration.describe()
# Out:
# (count     148.000000
#  mean     2409.229730
#  std       751.544705
#  min       480.000000
#  25%      1746.000000
#  50%      2463.500000
#  75%      2940.000000
#  max      4980.000000
#  Name: duration_seconds, dtype: float64,
#  count     723.000000
#  mean     2032.253112
#  std       773.444860
#  min         0.000000
#  25%      1435.500000
#  50%      1883.000000
#  75%      2491.500000
#  max      7440.000000
#  Name: duration_seconds, dtype: float64)

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment </b>
#
# Isn't it strange that the outputs are identical? Always analyze the result, don't forget about it.
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Student сomments:</b> Again i beleive i was so thrilled the code worked that i didnt focus so much on the output, i will be better on this moving forward. </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 </h2>
#
# Yes, it happens sometimes :)
# </div>

# %% [markdown]
# ## Statistical Test
# Since we are comparing the means of two independent groups (rainy Saturdays vs. non-rainy Saturdays), we can use a two-sample t-test to determine if there is a statistically significant difference in the average ride durations.
# The two-sample t-test compares the means of two independent samples and tests whether the observed difference is statistically significant.The significance level represents the probability of rejecting the null hypothesis if it is actually true. A common significance level is 0.05 so we use that as our significance level. If the p-value is less than 0.05 we reject the null hypothesis. If the p-value is greater than 0.05 we can not reject the null hypothesis.

# %% [markdown]
# The null hypothesis: there is no difference in ride durations between rainy and non-rainy Saturdays.
#
# The alternative hypothesis: The average ride duration differs between rainy and non-rainy Saturdays.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
# Please add wordings for both hypotheses.
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2</h2>
#
#
# True. The Null hypothesis always states the equality.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Student сomments:</b> Updated </div>

# %%
from scipy import stats as st
import numpy as np

# Significance level 
alpha = 0.05
# Perform the two-sample t-test
results = st.ttest_ind(rainy_saturdays_duration, non_rainy_saturdays_duration, equal_var=False)
print('p_value: ', results.pvalue)

if results.pvalue < alpha:
    print("We reject the null hypothesis")
else: 
    print("We can't reject the null hypothesis")
# Out:
# p_value:  9.126383933880083e-08
# We reject the null hypothesis

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
# Pvalue should not be 0, 1, or Nan. Anytime you see these values, it may be a good idea to check the code or the arrays.
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2</h2>
#
#
# Good!
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Student сomments:</b> Thank you the code has been updated </div>

# %% [markdown]
# # Conclusion
#
# Based on the T-test result we reject the null hypothesis that there is no difference in ride durations between rainy and non-rainy Saturdays.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  </b>
#
# Please, don't forget to add the overall conclusion to your project: what has been done and what can be inferred from the results.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Student сomments:</b> Overall Conclusion has been added</div>

# %% [markdown]
# ## Project Summary
#
# The goal of this project was to analyze and extract actionable insights from available ride-sharing data, with a focus on understanding passenger preferences, ride patterns, and external factors such as weather. The project was divided into two main parts: Exploratory Data Analysis (EDA) and Hypothesis Testing.
#
# We imported two datasets and inspected the data types and cleaned any issues, ensuring columns were alike in data type and other columns were in their proper format. We identified the taxi companies with the highest number of rides during the selected period. We identified the neighborhoods with the highest average number of drop-offs, highlighting the demand for ride-sharing in specific areas.
#
# We created visualizations to display market leaders and high-demand areas in the city, both of which provide valuable data for Zuber’s operational and marketing strategies. It also highlights competitive dynamics that Zuber must navigate when launching its service.
#
# We tested the hypothesis that weather conditions (specifically rainy Saturdays) might affect the duration of rides from the Loop to O'Hare International Airport. We filtered rides to include only those on Saturdays and categorized them into rainy vs. non-rainy conditions. We performed an independent two-sample t-test to compare the average ride durations on rainy Saturdays vs. non-rainy Saturdays. This analysis is intended to help Zuber optimize its operations and improve its service offering in the competitive Chicago market.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2</h2>
#
# Good conclusion 👍
# </div>
