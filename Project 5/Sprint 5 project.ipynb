# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# <b>Hello!</b> We're glad to see you in code-reviewer territory. You've done a great job on the project, but let's get to know each other and make it even better! We have our own atmosphere here and a few rules:
#
#
# 1. I work as a code reviewer, and my main goal is not to point out your mistakes, but to share my experience and help you become a data analyst.
# 2. We speak on a first-come-first-served basis.
# 3. if you want to write or ask a question, don't be shy. Just choose your color for your comment.
# 4. this is a training project, you don't have to be afraid of making a mistake.
# 5. You have an unlimited number of attempts to pass the project.
# 6. Let's Go!
#
#
# ---
# I'll be color-coding comments, please don't delete them:
#
# <div class="alert alert-block alert-danger">✍
#
#
# __Reviewer's comment №1__
#
# Needs fixing. The block requires some corrections. Work can't be accepted with the red comments.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Reviewer's comment №1__
#
#
# Remarks. Some recommendations.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">✔️
#
#
# __Reviewer's comment №1__
#
# Success. Everything is done succesfully.
# </div>
#
# ---
#
# I suggest that we work on the project in dialogue: if you change something in the project or respond to my comments, write about it. It will be easier for me to track changes if you highlight your comments:
#
# <div class="alert alert-info"> <b>Student сomments:</b> Student answer..</div>
#
# All this will help to make the recheck of your project faster. If you have any questions about my comments, let me know, we'll figure it out together :)
#
# ---

# %% [markdown]
# # Project Objective
#
# As Data Analyst for the online video game store Ice. My task is to identify patterns that helps determine whether a game succeeds or not and provide valuable insight to the advertising and marketing department for the 2017 campaign. I'll be reveiwing historical data from the past few years leading up to 2016.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Reviewer's comment №1__
#
# An excellent practice is to describe the goal and main steps in your own words (a skill that will help a lot on a final project). It would be good to add the progress and purpose of the study.

# %% [markdown]
# <div class="alert alert-info"> <b>Student сomments:</b> Project Objective has been added</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Reviewer's comment №2__
#
# All right

# %% [markdown]
# # Step 1. Open the Data

# %%
# Import and read the CSV file. Study the general information of the dataset
import pandas as pd

# Path to the csv file 
file_path = '/datasets/games.csv'

# reading the csv file into a dataframe
df = pd.read_csv(file_path)

df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Reviewer's comment №1__
#
#
# I suggest separating logically different things:
#
#     - library imports
#     - data opening (this may not be a trivial process)
#     - working code
#
# This approach will improve code readability, reduce the time of searching for errors, if there are any, and exclude code re-execution
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Student сomments:</b> Noted moving forward this is something I will work on</div>

# %%
# retreive general information about the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
# get a statistical summary of the dataframe 
df.describe()
# Out:
#        Year_of_Release      NA_sales      EU_sales      JP_sales  \
# count     16446.000000  16715.000000  16715.000000  16715.000000
# mean       2006.484616      0.263377      0.145060      0.077617
# std           5.877050      0.813604      0.503339      0.308853
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2016.000000     41.360000     28.960000     10.220000
#
#         Other_sales  Critic_Score
# count  16715.000000   8137.000000
# mean       0.047342     68.967679
# std        0.186731     13.938165
# min        0.000000     13.000000
# 25%        0.000000     60.000000
# 50%        0.010000     71.000000
# 75%        0.030000     79.000000
# max       10.570000     98.000000

# %%
# Check for missing values 
df.isnull().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# NA_sales              0
# EU_sales              0
# JP_sales              0
# Other_sales           0
# Critic_Score       8578
# User_Score         6701
# Rating             6766
# dtype: int64

# %% [markdown]
# # Step 2. Prepare the Data

# %%
# Replace the column names and make them lowercase 
df.columns = [col.lower() for col in df.columns]
df.columns
df
# Out:
#                                 name platform  year_of_release         genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16711               LMA Manager 2007     X360           2006.0        Sports
# 16712        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16713               Spirits & Spells      GBA           2003.0      Platform
# 16714            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
# Remove missing values from the the year of release columns due to it being a very small portion of missing values of the dataframe, this approach should provide very minimum affect on the data analysis
df_cleaned = df.dropna(subset= ['year_of_release'])
(df_cleaned)
# Out:
#                                 name platform  year_of_release         genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16711               LMA Manager 2007     X360           2006.0        Sports
# 16712        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16713               Spirits & Spells      GBA           2003.0      Platform
# 16714            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
df_cleaned.isnull().sum()
# Out:
# name                  2
# platform              0
# year_of_release       0
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8463
# user_score         6607
# rating             6678
# dtype: int64

# %%
# Convert the data to the required types. Describe the columns where the data types have been changed and why.
df_cleaned[['name', 'genre']] = df_cleaned[['name', 'genre']].fillna('Unknown')
df_cleaned['rating'] = df_cleaned['rating'].fillna('E')
df_cleaned['year_of_release'] = df_cleaned['year_of_release'].astype(int)

df_cleaned
# Out:
# /opt/conda/envs/python3/lib/python3.9/site-packages/pandas/core/frame.py:3191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /tmp/ipykernel_94/4165052793.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['rating'] = df_cleaned['rating'].fillna('E')
# /tmp/ipykernel_94/4165052793.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# Replace 'tbd' with 'nan' in order to appl the segmentation-based imputation
df_cleaned['critic_score'] =pd.to_numeric(df_cleaned['critic_score'], errors='coerce')
df_cleaned['user_score'] = pd.to_numeric(df_cleaned['user_score'], errors='coerce')



# Provide a more context aware imputation to fill the missing values of both critic and user scores since a substantial amount of data is missing here.


df_cleaned['critic_score'] = df_cleaned.groupby('genre')['critic_score'].apply(lambda x: x.fillna(x.median()))
df_cleaned['user_score'] = df_cleaned.groupby('genre')['user_score'].apply(lambda x: x.fillna(x.median()))

df_cleaned
# Out:
# /tmp/ipykernel_94/1648919535.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['critic_score'] =pd.to_numeric(df_cleaned['critic_score'], errors='coerce')
# /tmp/ipykernel_94/1648919535.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['user_score'] = pd.to_numeric(df_cleaned['user_score'], errors='coerce')
# /opt/conda/envs/python3/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1117: RuntimeWarning: Mean of empty slice
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Reviewer's comment №1__
#
# Substituting missing values for the median/mean/zero can skew the data and introduce some problem in further analysis. Let me elaborate on the causes and consequences of this approach.
#
# 1. distortion of the distribution: When we replace missing values with the median, we are actually adding new values to the data set. This can lead to a shift in the distribution and distort the statistical properties of the data. Replacing by the median can make the data look more homogeneous than it actually is.
#
# 2. Possible consequences: Substituting missing values for the median can affect many aspects of data analysis:
#
#    - Statistical tests: Distorted data can lead to incorrect conclusions in statistical tests. The use of skewed data can lead to incorrect results in significance tests and estimation of effects between groups or conditions.
#
#    - Modeling: When distorted data are used to build models, models may also suffer from distortion and produce incorrect predictions or conclusions. This can be particularly important if missing values are associated with key model variables.
#
#    - Inferences and interpretation: Distorted data can lead to incorrect inferences and misinterpretation of results. For example, if missing values are associated with important factors, replacing with the median may lead to misunderstanding the effect of these factors on the variable under study.
#
#
#  So, instead of replacing missing values with median, it is recommended to apply other approaches to handle missing data such as:
#
# - Removing records with missing values: If the number of records with missing values is small compared to the total amount of data, deleting these records may be a reasonable approach.
#
# - Data Imputation: Using more sophisticated techniques such as data imputation can help recover missing values based on other variables in the dataset.For example, machine learning models can be used to predict missing values based on the available data.
# It is important to assess the reason for missing values and choose an approach to handle them based on the specifics of the data and the objectives of the study.Proper handling of missing values helps to maintain the accuracy and reliability of data analysis.

# %% [markdown]
# <div class="alert alert-info"> <b>Student сomments:</b> my logic and understanding in what i was attempting was that i didnt want to generate numbers from out of the blue and was only trying to use the data provided so what i was saying is that no data is the same as nothing or zero (maybe a bit to literal and also inaccurate.. as i didnt think about or wasnt aware of how that would affect statistical tests and such) I understand what you are saying now and will correct</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Reviewer's comment №2__
#
# Ok

# %% [markdown]
# # 2.3
#
# The year_of_release column was changed from float64 data type to int data type as no decimals are needed to express what year the games were released.
#
# There were several columns that contained missing values. Categorical name columns with missing information (name & genre) were filled with unknown to satisfy missing data. inserting unknown fills the null value without distorting any of the data needing to be processed. The 'rating' columns null values were filled with 'E' consistent with other games as all games are rated E for everyone.
#
# The columns critic_score and user_score were both missing significant portion of values. This could be due to users and critics both both bypassing the ratings when prompted. These values were filled with 0 due to the fact that a score of 0 is possible option. A score of 0 gives an interpretation that is equal to that of having no score at all but also satisfies our missing values in the dataset. This was done in an attempt to not skew data and use only the information provided.

# %%
df.isnull().sum()
# Out:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         6701
# rating             6766
# dtype: int64

# %%
df['total_sales'] = df[['na_sales','eu_sales','jp_sales','other_sales']].sum(axis=1).round().astype(int)
df
# Out:
#                                 name platform  year_of_release         genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16711               LMA Manager 2007     X360           2006.0        Sports
# 16712        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16713               Spirits & Spells      GBA           2003.0      Platform
# 16714            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
# Check for duplicate rows 
duplicates = df.duplicated()

df[duplicates]
# Out:
# Empty DataFrame
# Columns: [name, platform, year_of_release, genre, na_sales, eu_sales, jp_sales, other_sales, critic_score, user_score, rating, total_sales]
# Index: []

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Reviewer's comment №1__
#
# There is no check for duplicates. Please add them.

# %% [markdown]
# <div class="alert alert-info"> <b>Student сomments:</b> Checking for duplicates has been done</div>

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Reviewer's comment №1__
#
# Please, add an intermediate conclusion about this introductory part. What have been done, what hypotheses about the data do we have and what we are going to do next

# %% [markdown]
# <div class="alert alert-info"> <b>Student сomments:</b> i was under the impression that steps 2.3 checked off this as a requirement, nevertheless it has been updated to provide further context and explain further what steps have been done with the data and next steps</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Reviewer's comment №2__
#
# Great

# %% [markdown]
# # Intermediate Conclusion
#
# Data has been cleaned and prepared to be analyzed at this point we have replaced missing values from the dataset as there wew several columns that contained missing information.Categorical name columns with missing information (name & genre) were filled with unknown to satisfy missing data. inserting unknown fills the null value without distorting any of the data needing to be processed. The 'rating' columns null values were filled with 'E' consistent with other games as all games are rated E for everyone.
# The columns critic_score and user_score were both missing significant portion of values. This could be due to users and critics both both bypassing the ratings when prompted. These values were filled by grouping each score by genre and filling missing values by the median of that genre. The year_of_release column was changed from float64 data type to int data type as no decimals are needed to express what year the games were released.

# %% [markdown]
# # 3. Analyze the Data

# %%
# group the data by release year and count the number of games in each  year 
games_by_year = df_cleaned.groupby('year_of_release').size().reset_index(name='game_count')
games_by_year
# Out:
#     year_of_release  game_count
# 0              1980           9
# 1              1981          46
# 2              1982          36
# 3              1983          17
# 4              1984          14
# 5              1985          14
# 6              1986          21
# 7              1987          16
# 8              1988          15
# 9              1989          17
# 10             1990          16
# 11             1991          41
# 12             1992          43
# 13             1993          62
# 14             1994         121
# 15             1995         219
# 16             1996         263
# 17             1997         289
# 18             1998         379
# 19             1999         338
# 20             2000         350
# 21             2001         482
# 22             2002         829
# 23             2003         775
# 24             2004         762
# 25             2005         939
# 26             2006        1006
# 27             2007        1197
# ...

# %%
import matplotlib.pyplot as plt 
import pandas as pd 

plt.figure(figsize=(10,6))
plt.plot(games_by_year['year_of_release'], games_by_year['game_count'], marker='o', color='b', linestyle='-', markersize=5)
plt.title('Number of Games released over the years', fontsize=14)
plt.xlabel('Year of Release', fontsize=12)
plt.ylabel('Game Count', fontsize=12)
plt.grid(True)

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Reviewer's comment №1__
#
# No visualization, please add

# %% [markdown]
#  <div class="alert alert-info"> <b>Student сomments:</b> Visualization has been added</div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
# __Reviewer's comment №2__
#
#
# It would be nice to add visualizations. In order to build a graph, you need to group the data (in our case, the year of release and quantity)
#
# ![image-3.png](attachment:image-3.png)
#
# ---
# Next, using the sns library (it's powerful, and you can do anything with it). From the data in the grouped table, plot the graph. You can have it if you want =) The main thing is to play around with the arguments and figure it out. In future projects you will build powerful graphs, this skill will come in handy there
#
# ![image-4.png](attachment:image-4.png)
# </div>

# %% [markdown]
# The data for each period is significant in the fact it highlights when in time there was a surge and boom in the amount of games being released. It also shows clear trends of increase and decrease of games released over time.

# %%
df_cleaned['total_sales']  = df_cleaned['na_sales'] + df_cleaned['eu_sales'] + df_cleaned['jp_sales'] + df_cleaned['other_sales']

df_cleaned['total_sales'] = df_cleaned['total_sales'].round(0).astype(int)
(df_cleaned['total_sales'])





# Group sales by platform and year and sum the sales for each year
platform_sales = df_cleaned.groupby('platform')['total_sales'].sum().reset_index(name='platform_sales')
# Sort by total sales 
top_platforms = platform_sales.sort_values(by='platform_sales', ascending=False)

top_platforms
# Out:
# /tmp/ipykernel_94/4288894351.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['total_sales']  = df_cleaned['na_sales'] + df_cleaned['eu_sales'] + df_cleaned['jp_sales'] + df_cleaned['other_sales']
# /tmp/ipykernel_94/4288894351.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['total_sales'] = df_cleaned['total_sales'].round(0).astype(int)
#    platform  platform_sales
# 16      PS2            1043
# 28     X360             855
# 17      PS3             837
# ...

# %%
#filter the original dataframe for top platforms 
top_platform_sales = df_cleaned[df_cleaned['platform'].isin(top_platforms['platform'])]
# group by platform and year to sum sales for each year 
top_platform_sales
platform_sales_by_year = top_platform_sales.groupby(['platform', 'year_of_release'])['total_sales'].sum().reset_index()

platform_sales_by_year.head()
# Out:
#   platform  year_of_release  total_sales
# 0     2600             1980           10
# 1     2600             1981           29
# 2     2600             1982           29
# 3     2600             1983            4
# 4     2600             1984            0

# %%
# plot the distribution for each top platform
import matplotlib.pyplot as plt 
plt.figure(figsize=(12,8))

for platform in top_platforms['platform']:
    platform_data = platform_sales_by_year[platform_sales_by_year['platform'] == platform]
    plt.plot(platform_data['year_of_release'], platform_data['total_sales'], label= platform)
    
plt.xlabel('Year')
plt.ylabel('Global Sales (in millions)')
plt.title('Sales Distribution Over Time for Top Platforms')
plt.legend()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
# __Reviewer's comment №1__
#
#
# PS2 data distribution looks like a cat ^^

# %%
# define recent years 
recent_years = df_cleaned[df_cleaned['year_of_release'] >= 2014]

#group sales by platform for recent years 
platforms_recent_sales = recent_years.groupby('platform')['total_sales'].sum()

# find platforms that have zero sales in recent years 
faded_platforms = platforms_recent_sales[platforms_recent_sales == 0].index

#display the platforms that have zero sales in recent years 

print(f"Platforms with zero sales after 2015:{list(faded_platforms)}")

platforms_recent_sales
# Out:
# Platforms with zero sales after 2015:['PSP']
# platform
# 3DS      70
# PC       16
# PS3      52
# PS4     264
# PSP       0
# PSV       5
# Wii       5
# WiiU     39
# X360     38
# XOne    120
# Name: total_sales, dtype: int64

# %%
# Filter the original data for platforms that faded and check their sales before 2015
historical_data = df_cleaned[df_cleaned['platform'].isin(faded_platforms) & (df_cleaned['year_of_release'] < 2015)]

historical_data
# group by platform to check total sales before 2015
historical_sales = historical_data.groupby('platform')['total_sales'].sum()

# Display platforms that were popular before fading
print(f"Platforms that used to be popular: {historical_sales[historical_sales > 0]}")
# Out:
# Platforms that used to be popular: platform
# PSP    191
# Name: total_sales, dtype: int64

# %%
# How long does it generally take for new platforms to appear and old ones to fade?
platform_lifecycles = df_cleaned.groupby('platform')['year_of_release'].agg(['min', 'max']).reset_index()

#Add a column for lifespan of platform 
platform_lifecycles['lifespan'] = platform_lifecycles['max'] - platform_lifecycles['min']

platform_lifecycles
# Out:
#    platform   min   max  lifespan
# 0      2600  1980  1989         9
# 1       3DO  1994  1995         1
# 2       3DS  2011  2016         5
# 3        DC  1998  2008        10
# 4        DS  1985  2013        28
# 5        GB  1988  2001        13
# 6       GBA  2000  2007         7
# 7        GC  2001  2007         6
# 8       GEN  1990  1994         4
# 9        GG  1992  1992         0
# 10      N64  1996  2002         6
# 11      NES  1983  1994        11
# 12       NG  1993  1996         3
# 13       PC  1985  2016        31
# 14     PCFX  1996  1996         0
# 15       PS  1994  2003         9
# 16      PS2  2000  2011        11
# 17      PS3  2006  2016        10
# 18      PS4  2013  2016         3
# 19      PSP  2004  2015        11
# 20      PSV  2011  2016         5
# 21      SAT  1994  1999         5
# 22      SCD  1993  1994         1
# 23     SNES  1990  1999         9
# 24     TG16  1995  1995         0
# 25       WS  1999  2001         2
# ...

# %%
platform_lifecycles_sorted = platform_lifecycles.sort_values(by='min')

platform_lifecycles_sorted
# Out:
#    platform   min   max  lifespan
# 0      2600  1980  1989         9
# 11      NES  1983  1994        11
# 4        DS  1985  2013        28
# 13       PC  1985  2016        31
# 5        GB  1988  2001        13
# 23     SNES  1990  1999         9
# 8       GEN  1990  1994         4
# 9        GG  1992  1992         0
# 22      SCD  1993  1994         1
# 12       NG  1993  1996         3
# 21      SAT  1994  1999         5
# 15       PS  1994  2003         9
# 1       3DO  1994  1995         1
# 24     TG16  1995  1995         0
# 14     PCFX  1996  1996         0
# 10      N64  1996  2002         6
# 3        DC  1998  2008        10
# 25       WS  1999  2001         2
# 6       GBA  2000  2007         7
# 29       XB  2000  2008         8
# 16      PS2  2000  2011        11
# 7        GC  2001  2007         6
# 19      PSP  2004  2015        11
# 28     X360  2005  2016        11
# 17      PS3  2006  2016        10
# 26      Wii  2006  2016        10
# ...

# %% [markdown]
# Determine what period you should take data for to build a model for 2017.
#
# Platforms that are now outdated wont help predict data for 2017 performance so that data should be excluded.
# Popular platforms typically have a lifecycle of around 7-15 years. Newer platforms that were still active should be included in the data for the 2017 market.
# We will focus on platforms released within the years 2010-2016. Wee are chosing this data period due to newer platforms like PS4, Xbox One, and Mimtendo Switch were becoming more relevant and ending in 2016 due to this being the last year of information we have.

# %%
# Filter data for 2010-2016
filtered_df = df_cleaned[(df_cleaned['year_of_release'] >= 2010) & (df_cleaned['year_of_release'] <= 2016)]
filtered_df
# Out:
#                                  name platform  year_of_release         genre  \
# 14                 Kinect Adventures!     X360             2010          Misc
# 16                 Grand Theft Auto V      PS3             2013        Action
# 23                 Grand Theft Auto V     X360             2013        Action
# 27        Pokemon Black/Pokemon White       DS             2010  Role-Playing
# 29     Call of Duty: Modern Warfare 3     X360             2011       Shooter
# ...                               ...      ...              ...           ...
# 16703                Strawberry Nauts      PSV             2016     Adventure
# 16707                Aiyoku no Eustia      PSV             2014          Misc
# 16710   Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16712         Haitaka no Psychedelica      PSV             2016     Adventure
# 16714             Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
# __Reviewer's comment №1__
#
#
# For the purpose of predicting sales for the next year, even traditional businesses rarely take data for more than 2-3 years. And in such a dynamically changing industry as computer games, you shouldn't take too long a time interval - otherwise you're bound to capture trends that are already outdated. But you shouldn't take too short a period either

# %%
# Group by platform and sum the sales to get the total sales for each platform
filtered_sales = filtered_df.groupby('platform')['total_sales'].sum().reset_index()

# Sort the platforms by total sales to find the leading platforms 
leading_platforms = filtered_sales.sort_values(by='total_sales', ascending=False)

leading_platforms
# Out:
#    platform  total_sales
# 4       PS3          521
# 10     X360          495
# 5       PS4          290
# 0       3DS          210
# 8       Wii          182
# 11     XOne          137
# 2        PC           92
# 1        DS           77
# 9      WiiU           70
# 6       PSP           27
# 7       PSV           22
# 3       PS2            2

# %% [markdown]
# The PS3 platforms stands as the current sales leader.

# %% [markdown]
# Analyze Growth or Decline of Platforms

# %%
# Group sales by platform and year 
filtered_sales_by_year = filtered_df.groupby(['platform', 'year_of_release'])['total_sales'].sum().reset_index()

# Plot the sales trends for each leading platform
import matplotlib.pyplot as plt 

plt.figure(figsize=(12,8))

# loop over the leading platforms to plot their trends over a period of time
for platform in leading_platforms['platform'].head(7):
    filtered_data = filtered_sales_by_year[filtered_sales_by_year['platform'] == platform]
    plt.plot(filtered_data['year_of_release'], filtered_data['total_sales'], label=platform)
    
plt.xlabel('Year')
plt.ylabel('Total Sales (in millions)')
plt.title('Sales Trends for Leading Platforms (2010-2016)')
plt.legend()
plt.show()

# %% [markdown]
# Based on the sales trends, you see growing platforms with increasing sales from year to year, such as PS4 or Xbox One, may be considered profitable for future growth. Platforms with decreasing sales may not be profitable in the future as their sales decline each year.

# %%
df_cleaned['total_sales']  = df_cleaned['na_sales'] + df_cleaned['eu_sales'] + df_cleaned['jp_sales'] + df_cleaned['other_sales']

df_cleaned['total_sales'] = df_cleaned['total_sales'].round(0).astype(int)
(df_cleaned['total_sales'])
# Out:
# /tmp/ipykernel_94/2776500137.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['total_sales']  = df_cleaned['na_sales'] + df_cleaned['eu_sales'] + df_cleaned['jp_sales'] + df_cleaned['other_sales']
# /tmp/ipykernel_94/2776500137.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['total_sales'] = df_cleaned['total_sales'].round(0).astype(int)
# 0        83
# 1        40
# 2        36
# 3        33
# 4        31
#          ..
# 16710     0
# 16711     0
# ...

# %%
# Create a box plot 
import seaborn as sns
import matplotlib.pyplot as plt 

plt.figure(figsize=(12, 8))

sns.boxplot(x='platform', y='total_sales', data=df_cleaned)


plt.xlabel('Platform')
plt.ylabel('Total Sales (in millions)')
plt.title('Box Plot of Global Sales by Platform')

plt.xticks(rotation=90)

plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='platform', y='total_sales', data=df_cleaned)

plt.ylim(0,8)

plt.title('Box Plot of Total Sales (Lower Part Only)')
plt.xlabel('Platform')
plt.ylabel('Total Sales (in millions)')

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Reviewer's comment №1__
#
# Unfortunately, this graph only shows the outliers, and does not show the median and 75% quantile. For more reasonable conclusions it is necessary to make an additional graph, where only the lower part of the boxplots will be displayed. This can be achieved, for example, by setting the parameter ylim
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Student сomments:</b> Additional visualization has been added</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Reviewer's comment №2__
# Now correct

# %% [markdown]
# There are significant differences in the sales of a few games on certain platforms as evident by the outliers of a few games produced from those platforms. Platforms with narrower boxes and fewer outliers indicate that most games on that platform were similiar in sales performance across most games on that platform.
#
# Some platforms, especially newer ones tend to have higher sales due to more popular titles and better capabilities.
# Platforms like PS4, XBOX one, and Wii have higher average sales compared to older or less popular platforms.
# This analysis helps identify which platforms have been the most successful and profitable in terms of game sales.

# %%
# Calculate average sales for each platform 
avg_sales_by_platform = df_cleaned.groupby('platform')['total_sales'].mean().reset_index()

avg_sales_by_platform = avg_sales_by_platform.sort_values(by='total_sales', ascending=False)

avg_sales_by_platform
# Out:
#    platform  total_sales
# 11      NES     2.530612
# 5        GB     2.505155
# 8       GEN     1.000000
# 18      PS4     0.739796
# 23     SNES     0.723849
# 28     X360     0.693994
# 17      PS3     0.640888
# 0      2600     0.637931
# 26      Wii     0.601089
# 10      N64     0.591772
# 30     XOne     0.554656
# 15       PS     0.526891
# 16      PS2     0.490362
# 27     WiiU     0.476190
# 2       3DS     0.410156
# 22      SCD     0.333333
# 4        DS     0.291843
# 6       GBA     0.284834
# 7        GC     0.263838
# 29       XB     0.224159
# 13       PC     0.214211
# 3        DC     0.173077
# 25       WS     0.166667
# 19      PSP     0.160101
# 21      SAT     0.069364
# 20      PSV     0.051282
# 24     TG16     0.000000
# 12       NG     0.000000
# 1       3DO     0.000000
# 14     PCFX     0.000000
# 9        GG     0.000000

# %% [markdown]
# # 3.7  Build a scatterplot and calculate the correlation between reviews and sales.

# %%
# select a popular platform
ps4_data = df_cleaned[df_cleaned['platform'] == 'PS4']

# Create scatter plots for user score vs total sales and critic score vs total sales
import matplotlib.pyplot as plt 
import seaborn as sns 

plt.figure(figsize=(12,6))

plt.subplot(1,2,1)
sns.scatterplot(x='user_score', y='total_sales', data=ps4_data)
plt.title('User Score vs Total Sales')
plt.xlabel('User Score')
plt.ylabel('Total Sales (in millions)')

plt.subplot(1,2,2)
sns.scatterplot(x='critic_score', y='total_sales', data=ps4_data)
plt.title('Critic Score vs Total Sales')
plt.xlabel('Critic Score')
plt.ylabel('Total Sales (in millions)')

plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Reviewer's comment №1__
#
# No visualization, please fix it

# %% [markdown]
# <div class="alert alert-info"> <b>Student сomments:</b> Visualization has been fixed</div>

# %%
# Calculate the correlation between User Score and Total Sales
user_score_corr = ps4_data['user_score'].corr(ps4_data['total_sales'])

# Calculate the correlation between Critic Score and Total Sales
critic_score_corr = ps4_data['critic_score'].corr(ps4_data['total_sales'])

# Print the correlations
print(f"Correlation between User Score and Total Sales: {user_score_corr:.2f}")
print(f"Correlation between Critic Score and Total Sales: {critic_score_corr:.2f}")
# Out:
# Correlation between User Score and Total Sales: -0.07
# Correlation between Critic Score and Total Sales: 0.34

# %% [markdown]
# #  Correlation Conclusions
#
# The scatterplot  and the correlation value shows how much impact user reviews have on game sales for the PS4. A positive correlation means higher user scores tends to result in more sales, while a weak or negative correlation means there may be little or no relation at all.
#
# Similarly the correlation between professional reviews and sales will indicate whether higher scores drives more sales.
# As it pertains to most games you might observe a positvie correlation between critic scores and total sales as critic reviews tend to have an influence on game sales. this could be do to features in the media or game rating platforms.
# User scores correlation may vary as they can have weaker impact on sales compared to a professional review .

# %%
# Group data by genre and calculate total sales for each genre
genre_sales = df_cleaned.groupby('genre')['total_sales'].sum().sort_values(ascending=False)

# Plot total sales by genre
plt.figure(figsize=(10, 6))
sns.barplot(x=genre_sales.index, y=genre_sales.values, palette='viridis')
plt.title('Total Sales by Genre')
plt.xlabel('Genre')
plt.ylabel('Total Sales (in millions)')
plt.xticks(rotation=45)
plt.show()

# Create a boxplot to show the distribution of sales by genre
plt.figure(figsize=(12, 8))
sns.boxplot(x='genre', y='total_sales', data=df_cleaned)
plt.title('Sales Distribution by Genre')
plt.xlabel('Genre')
plt.ylabel('Global Sales (in millions)')
plt.xticks(rotation=45)
plt.show()


plt.figure(figsize=(12, 8))
sns.boxplot(x='genre', y='total_sales', data=df_cleaned)
plt.title('Sales Distribution by Genre (Lower Only)')

plt.ylim(0,10)


plt.xlabel('Genre')
plt.ylabel('Global Sales (in millions)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Generalization and Conclusion
#
# Genres like Action, Shooter, and Sports are generally top sellers because they appeal to broader audiences, they have stronger franchises, and benefit from repeat purchases due to their competitive nature. While genres such as puzzle, strategy, and adventure tend to appeal to more of a niche crowd and may have less frequent major releases and also may not have a multi-player nature to them which alone can contribute to lower sales overall. The distribution of sales within each genre may vary widely, which indicates that a few successful titles (as evidenced by the outliers) can heavily influence the average sales, especially within genres like Action and Shooter.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Reviewer's comment №1__
# Missing task. Total sales is a poor metric for finding the most profitable genre. High overall sales numbers can hide a lot of small games with low sales. Or 2-3 stars and a bunch of failures. It's better to find a genre where games consistently bring in high revenue - for that it's worth considering average or median sales
#
# ---
#
# Ideally, visualize the data distribution using boxplot()
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Student сomments:</b> Task has been completed </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Reviewer's comment №2__
#
# Brilliant

# %% [markdown]
# # 4.1 Region Profiles

# %%
# Group by platform and region sales 
top_platforms_na = df.groupby('platform')['na_sales'].sum().reset_index().sort_values(by='na_sales', ascending=False).head(5)
top_platforms_eu = df.groupby('platform')['eu_sales'].sum().reset_index().sort_values(by='eu_sales', ascending=False).head(5)
top_platforms_jp = df.groupby('platform')['jp_sales'].sum().reset_index().sort_values(by='jp_sales', ascending=False).head(5)

# Display the top 5 platforms for each region 
print("Top 5 Platforms in North America (NA):\n", top_platforms_na)



print("Top 5 Platforms in Europe (EU):\n", top_platforms_eu)



print("Top 5 Platforms in Japan (JP):\n", top_platforms_jp)
# Out:
# Top 5 Platforms in North America (NA):
#     platform  na_sales
# 28     X360    602.47
# 16      PS2    583.84
# 26      Wii    496.90
# 17      PS3    393.49
# 4        DS    382.40
# Top 5 Platforms in Europe (EU):
#     platform  eu_sales
# 16      PS2    339.29
# 17      PS3    330.29
# 28     X360    270.76
# 26      Wii    262.21
# 15       PS    213.61
# Top 5 Platforms in Japan (JP):
#     platform  jp_sales
# 4        DS    175.57
# 15       PS    139.82
# 16      PS2    139.20
# 23     SNES    116.55
# 2       3DS    100.67

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Reviewer's comment №1__
#
#
# It would be nice to visualize this data with a pie or bar chart

# %% [markdown]
# In the North American region the platforms XBOX, Playstation, and Nintendo tend to dominate in sales. In both regions of Europe and Japan, Playstation and Nintendo also share strong sales numbers, while the Xbox has a lesser share of the market as compared to North America.

# %%
# Identify the top 5 genres for each region and explain the differences. 
top_genres_na = df.groupby('genre')['na_sales'].sum().reset_index().sort_values(by='na_sales', ascending=False).head(5)
top_genres_eu = df.groupby('genre')['eu_sales'].sum().reset_index().sort_values(by='eu_sales', ascending=False).head(5)
top_genres_jp = df.groupby('genre')['jp_sales'].sum().reset_index().sort_values(by='jp_sales', ascending=False).head(5)

print("Top 5 Genres in North America (NA):\n", top_genres_na)
print("Top 5 Genres in Europe (EU):\n", top_genres_eu)
print("Top 5 Genres in Japan (JP):\n", top_genres_jp)
# Out:
# Top 5 Genres in North America (NA):
#         genre  na_sales
# 0     Action    879.01
# 10    Sports    684.43
# 8    Shooter    592.24
# 4   Platform    445.50
# 3       Misc    407.27
# Top 5 Genres in Europe (EU):
#        genre  eu_sales
# 0    Action    519.13
# 10   Sports    376.79
# 8   Shooter    317.34
# 6    Racing    236.51
# 3      Misc    212.74
# Top 5 Genres in Japan (JP):
#             genre  jp_sales
# 7   Role-Playing    355.41
# 0         Action    161.43
# 10        Sports    135.54
# 4       Platform    130.83
# 3           Misc    108.11

# %% [markdown]
# Action and sports games dominate both the North America and European markets as the top 3 in both are identical. Japan prefers role playing games as a favorite with action and sports coming in afterwards.

# %%
# Group by ESRB and region sales to display sales distribution between regions 
esrb_na = df.groupby('rating')['na_sales'].sum().reset_index().sort_values(by='na_sales', ascending=False)
esrb_eu = df.groupby('rating')['eu_sales'].sum().reset_index().sort_values(by='eu_sales', ascending=False)
esrb_jp = df.groupby('rating')['jp_sales'].sum().reset_index().sort_values(by='jp_sales', ascending=False)

print("ESRB Ratings and Sales in North America (NA):\n", esrb_na)
print("ESRB Ratings and Sales In Europe (EU):\n", esrb_eu)
print("ESRB Ratings and Sales in Japan (JP):\n", esrb_jp)
# Out:
# ESRB Ratings and Sales in North America (NA):
#    rating  na_sales
# 1      E   1292.99
# 7      T    759.75
# 5      M    748.48
# 2   E10+    353.32
# 4    K-A      2.56
# 3     EC      1.53
# 0     AO      1.26
# 6     RP      0.00
# ESRB Ratings and Sales In Europe (EU):
#    rating  eu_sales
# 1      E    710.25
# 5      M    483.97
# 7      T    427.03
# 2   E10+    188.52
# 0     AO      0.61
# 4    K-A      0.27
# 3     EC      0.11
# 6     RP      0.08
# ESRB Ratings and Sales in Japan (JP):
#    rating  jp_sales
# 1      E    198.11
# 7      T    151.40
# 5      M     64.24
# 2   E10+     40.20
# 4    K-A      1.46
# 0     AO      0.00
# 3     EC      0.00
# 6     RP      0.00

# %% [markdown]
# The data supports ratings tend to play a factor in all regions as games with an E rating for everyone typically has the most the sales. All regions shared the same top 3  in sales per rating but id be interested to know exactly how much a rating plays a fact in a purchase as compared to the genre or game itself.

# %% [markdown]
# # 5 Testing Hypotheses

# %% [markdown]
# Null Hypothesis: The average user ratings for Xbox One and PC are the same.
# Alternative Hypothesis: The average user ratings for Xbox One and PC are different.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Reviewer's comment №1__
#
# Correct interpretation of the Null and Alternative hypotheses

# %%
# Run A two tail test to test if means are different 
from scipy import stats as st

df_cleaned['user_score'] = pd.to_numeric(df_cleaned['user_score'], errors='coerce')

xbox_data = df_cleaned[df_cleaned['platform'] == 'XOne']['user_score'].dropna()
pc_data = df_cleaned[df_cleaned['platform'] == 'PC']['user_score'].dropna()

alpha = 0.05
results = st.ttest_ind(xbox_data, pc_data)

print('p_value: ', results.pvalue)

if results.pvalue < alpha: 
    print('We reject the nully hypothesis')
else: 
    print("We can't reject the null hypothesis")
# Out:
# p_value:  3.154185891445344e-05
# We reject the nully hypothesis
# /tmp/ipykernel_94/758011290.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['user_score'] = pd.to_numeric(df_cleaned['user_score'], errors='coerce')

# %% [markdown]
# The null hypothesis was formulated as a default assumption. A common value is 0.05 was chosen as the P-value meaning we are willing to accept a 5% chance of incorrectly rejecting the null hypothesis when it is true. This level is widely accepted in statiscal analysis.

# %% [markdown]
# Null Hypothesis: The average user ratings for action and sports genres are the same.
#
# Alternative Hypothesis: The average user ratings for action and sports games are different.

# %%
print(df_cleaned)
# Out:
#                                 name platform  year_of_release         genre  \
# 0                         Wii Sports      Wii             2006        Sports
# 1                  Super Mario Bros.      NES             1985      Platform
# 2                     Mario Kart Wii      Wii             2008        Racing
# 3                  Wii Sports Resort      Wii             2009        Sports
# 4           Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16711               LMA Manager 2007     X360             2006        Sports
# 16712        Haitaka no Psychedelica      PSV             2016     Adventure
# 16713               Spirits & Spells      GBA             2003      Platform
# 16714            Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %%
from scipy import stats as st

# Run a two tail test to test if there is and differance in user ratings. 

action_data = df_cleaned[df_cleaned['genre'] == 'Action']['user_score'].dropna()
sports_data =df_cleaned[df_cleaned['genre'] == 'Sports']['user_score'].dropna()

alpha = 0.05
results = st.ttest_ind(action_data, sports_data)

print('p_value: ', results.pvalue)

if results.pvalue < alpha:
    print('We reject the null hypothesis')
else: 
    print("We can't reject the null hypothesis")
# Out:
# p_value:  0.4059173001251194
# We can't reject the null hypothesis

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Reviewer's comment №1__
# The second hypothesis is missing. Please add

# %% [markdown]
# <div class="alert alert-info"> <b>Student сomments:</b> Task has been completed </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Reviewer's comment №2__
# The result `nan` is incorrect values in the hypothesis. Please correct it

# %% [markdown]
# <div class="alert alert-info"> <b>Student сomments:</b> Task has been completed, the problem was the letters A and S in the genre column were not capitalized </div>

# %% [markdown]
# # Overall Conclusion
#
# This project offered a detailed analysis of the video game market using data-driven methods. By examining sales trends across platforms, regions, and genres, and exploring the impact of user and professional reviews on sales, it emphasized the importance of understanding regional preferences and consumer feedback for shaping successful game strategies. Hypothesis testing provided further insights into how different platforms and genres are perceived. Overall, the findings can guide game developers, marketers, and publishers in making more informed decisions about future game releases, marketing strategies, and platform partnerships, leading to improved business alignment and higher sales.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Reviewer's comment №1__
#
#
# Please correct the conclusions after correction

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Reviewer's comment №3__
#
#
# Otherwise it's great😊. Your project is begging for github =)
#
# Congratulations on the successful completion of the project 😊👍
# And I wish you success in new works 😊
