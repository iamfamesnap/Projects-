# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 2</b>
#
# Thank you for the updates! My new comments have digit 2.
#
#
# I do not have any questions, so I can accept the project now.
#
#
# If you are interested in this topic, please take a look at the small [Time Series Course](https://www.kaggle.com/learn/time-series) on Kaggle. There are just several lessons there, and in the end of this course you will apply your knowledge on the sales dataset that is provided for the ongoing [Store Sales Time Series Forecasting Competition](https://www.kaggle.com/competitions/store-sales-time-series-forecasting) with no rewards except for knowledge :) You can use their dataset for your practice and you can submit your notebook to run the model on the hidden test subset.
#
#
# Congratulations and good luck!
#
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment</b>
#
# Hi! Congratulations on submitting another project! 🎉
#
#
# Before we start, I want to pay your attention to the color marking:
#
#
#
#
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
#
# Great solutions and ideas that can and should be used in the future are in green comments. Some of them are:
#
#
# - You have successfully prepared the subsets. It is important to split the data correctly in order to ensure there's no intersection;
#
#
# - You have successfully investigated the data we have;
#
#
#
# - Trained and compared several models. It is not enough to just train a model. We also need to analyze the results and compare different models. Very good!
#
#
#
# - Wrote an excellent conclusion that shows how the project met its objectives. Good job!
#
# </div>
#
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment </b>
#
# Yellow color indicates what should be optimized. This is not necessary, but it will be great if you make changes to this project. I've left several recommendations throughout the project.
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment </b>
#
# Issues that must be corrected to achieve accurate results are indicated in red comments. Please note that the project cannot be accepted until these issues are resolved. More specifically:
#
#
# - Please add conclusions in the EDA section. Without conclusions, it may be hard to a reader to understand the charts.
#
#
# - Please add a deeper time series analysis. Is there any trend or seasonality in the data?
#
#
#
# - Please try to implement hyperparameter tuning for at least one of the models.
#
#
#
# - Please don't use the test subset until you move on to the final testing.
#
#
#
# - In the final testing section, we are supposed to make a predition using the best model only. So please train and tune all models first and then conduct the final test.
#
#
#
#
# </div>
# <hr>
#
# <font color='dodgerblue'>**To sum up:**</font> thank you very much for submitting the project! You did a fantastic job here. You have successfully trained several models and analyzed time series, which is great! The project is well-structured, and meets the objective: a forecasting model with RMSE < 48 was successfully built and tested. The results are represented and interpreted effectively. However, there're a couple of issues that need your attention. Would you take a look at my comments?
#
#
# <hr>
#
# Please use some color other than those listed to highlight answers to my comments.
# I would also ask you **not to change, move or delete my comments** to make it easier for me to navigate during the next review.
#
#
#
# <hr>
#
# ✍️ Here's a [link](https://machinelearningmastery.com/autoregression-models-time-series-forecasting-python/) to the article about the autoregression models that you may find interesting.
#
#
# [Here](https://medium.com/@soumyachess1496/cross-validation-in-time-series-566ae4981ce4) you can read about cross-validation with time series.
#
#
#
# <hr>
#
# 📌 Please feel free to schedule a 1:1 sessions with our tutors or TAs Feel free to book 1-1 session [here](https://calendly.com/tripleten-ds-experts-team), join daily coworking sessions, or ask questions in the sprint channels on Discord if you need assistance 😉
# </div>

# %% [markdown]
# # Project description
#
# Sweet Lift Taxi company has collected historical data on taxi orders at airports. To attract more drivers during peak hours, we need to predict the amount of taxi orders for the next hour. Build a model for such a prediction.
#
# The RMSE metric on the test set should not be more than 48.
#
# ## Project instructions
#
# 1. Download the data and resample it by one hour.
# 2. Analyze the data.
# 3. Train different models with different hyperparameters. The test sample should be 10% of the initial dataset.
# 4. Test the data using the test sample and provide a conclusion.
#
# ## Data description
#
# The data is stored in file `taxi.csv`. The number of orders is in the '*num_orders*' column.

# %% [markdown]
# ## Project Description
#
# Our goal for this project is to help our client Sweet Lift Taxi attract more drivers during peak hours. Our task is to build a model to help them be able to consistently do so. We will do so by building a few models to determine which one will best suit there needs by building the most robust and effective model. We will decide on and provide reasoning as to why such model will help Sweet Lift Taxi achieve its goals.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment </h2>
#
# It's great that the project has an introduction. A reader will easily understand what the project is about.
#
# </div>

# %% [markdown]
# ## Preparation

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn.ensemble import RandomForestRegressor 
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV

# %%
df = pd.read_csv('/datasets/taxi.csv', parse_dates=['datetime'], index_col ='datetime')
df
# Out:
#                      num_orders
# datetime
# 2018-03-01 00:00:00           9
# 2018-03-01 00:10:00          14
# 2018-03-01 00:20:00          28
# 2018-03-01 00:30:00          20
# 2018-03-01 00:40:00          32
# ...                         ...
# 2018-08-31 23:10:00          32
# 2018-08-31 23:20:00          24
# 2018-08-31 23:30:00          27
# 2018-08-31 23:40:00          39
# 2018-08-31 23:50:00          53
#
# [26496 rows x 1 columns]

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment </h2>
#
# The data was successfully read, good!
# </div>

# %%
len(df)
# Out:
# 26496

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 26496 entries, 2018-03-01 00:00:00 to 2018-08-31 23:50:00
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   num_orders  26496 non-null  int64
# dtypes: int64(1)
# memory usage: 414.0 KB

# %%
df.head()
# Out:
#                      num_orders
# datetime
# 2018-03-01 00:00:00           9
# 2018-03-01 00:10:00          14
# 2018-03-01 00:20:00          28
# 2018-03-01 00:30:00          20
# 2018-03-01 00:40:00          32

# %%
df['num_orders'].unique()
# Out:
# array([  9,  14,  28,  20,  32,  21,   7,   5,  17,  12,  19,  25,  22,
#          8,   6,   4,  10,  13,   2,   3,   0,   1,  11,  15,  16,  23,
#         18,  33,  24,  26,  30,  38,  34,  42,  31,  27,  36,  29,  35,
#         56,  37,  40,  39,  45,  49,  58,  68,  43,  53,  44,  41,  52,
#         46,  57,  47,  64,  61,  50,  48,  55,  62,  54,  71,  78, 119,
#         99,  51,  60,  87,  90,  94,  82,  80,  91,  76,  66,  65,  98,
#         81,  95,  67])

# %%
df.describe()
# Out:
#          num_orders
# count  26496.000000
# mean      14.070463
# std        9.211330
# min        0.000000
# 25%        8.000000
# 50%       13.000000
# 75%       19.000000
# max      119.000000

# %% [markdown]
# We need to resample the data by 1 hour to aggregate it into consistent, evenly spaced time intervals, which is crucial for time series modeling.

# %%
df = df.resample('1H').sum()
df
# Out:
#                      num_orders
# datetime
# 2018-03-01 00:00:00         124
# 2018-03-01 01:00:00          85
# 2018-03-01 02:00:00          71
# 2018-03-01 03:00:00          66
# 2018-03-01 04:00:00          43
# ...                         ...
# 2018-08-31 19:00:00         136
# 2018-08-31 20:00:00         154
# 2018-08-31 21:00:00         159
# 2018-08-31 22:00:00         223
# 2018-08-31 23:00:00         205
#
# [4416 rows x 1 columns]

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment</h2>
#
# Correct! We indeed need to use `sum`, not `mean`, since we need to forecast the total number of rides.
#
# </div>
#
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
# Please note that this method, as much as `duplicated()` or `dropna()` does not change anything. It only returns a new dataframe. So, in order to change the data, you need to re-write it as follows: `df = df.resample('1H').sum()`.
#
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 2 </h2>
#
# Correct!
# </div>

# %% [markdown]
# <div class="alert alert-info">
# I have re-wriiten the cell. </div>

# %% [markdown]
# ## Analysis

# %%
df['num_orders'].plot(figsize=(15, 5), title='Taxi Orders Over Time')
plt.xlabel('Time')
plt.ylabel('Number of Orders')
plt.show()

# %%
df.isnull().sum()
# Out:
# num_orders    0
# dtype: int64

# %%
df['num_orders'].rolling(window=24).mean().plot(title='Rolling 24h Mean')
plt.show()

# %%
# Perform seasonal decomposition on hourly resampled data
result = seasonal_decompose(df['num_orders'], model='additive', period=24)

# Plot the decomposition
result.plot()
plt.show()

# %%
df['num_orders'].hist(bins=30)
plt.title("Distribution of Hourly Taxi Orders")
plt.xlabel("Orders per Hour")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## Exploratory Data Analysis Insights
#
# The line plot shows that the number of taxi orders has been steadily increasing from March through the end of August. While there’s some short-term fluctuation (spikes and drops), the overall trend is upward, suggesting a growing demand for taxi services over time. The 24-hour rolling average further emphasizes this trend. It smooths out short-term variability and clearly reveals a gradual and consistent increase in taxi orders. From the seasonal decomposition, we observe a clear upward trend in taxi demand from March to the end of August 2018 supporting the info from previous charts, this suggest that the service is growing and that there is demand for it. There is also a reoccuring pattern each 24 hours. Which could suggest the consistency of clients around certain hours of the day.
# We also have no missing values here letting us know that our dataset is clean and complete. All of this insight is helpful for preparing for long-term operational scaling.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  </b>
#
#
# Please add a conclusion here. What can be inferred from these results? Is there any trend or seasonality? What about orders distribution? You can use `statsmodels` to analyze seasonality. There's a method `seasonal_decompose` there, which applies seasonal decomposition using moving averages. Apart from this, `statsmodels` has many interesting tools for time series analysis.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# I have updated the EDA with a conclusion.  </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 2 </h2>
#
# - Very good! So there's a visible trend by months. However, in the future, also check data from other years if the data is available. The sample size here is too small, so we can't draw conclusions on large timeframes. In this case, the increase in orders might simply be due to the business growth: more clients -> more orders.
#
#
#
# - Yes, we may have daily seasonality, which makes sense in such dataset.
# </div>

# %% [markdown]
# ## Feature Engineering
# Create time based features to better help the model.

# %%
df['hour'] = df.index.hour
df['dayofweek'] = df.index.dayofweek
df['month'] = df.index.month
df['lag_1'] = df['num_orders'].shift(1)
df['lag_24'] = df['num_orders'].shift(24)
df['rolling_mean_3'] = df['num_orders'].shift(1).rolling(3).mean()
df = df.dropna()

df
# Out:
#                      num_orders  hour  dayofweek  month  lag_1  lag_24  \
# datetime
# 2018-03-02 00:00:00          90     0          4      3   58.0   124.0
# 2018-03-02 01:00:00         120     1          4      3   90.0    85.0
# 2018-03-02 02:00:00          75     2          4      3  120.0    71.0
# 2018-03-02 03:00:00          64     3          4      3   75.0    66.0
# 2018-03-02 04:00:00          20     4          4      3   64.0    43.0
# ...                         ...   ...        ...    ...    ...     ...
# 2018-08-31 19:00:00         136    19          4      8  207.0    72.0
# 2018-08-31 20:00:00         154    20          4      8  136.0   142.0
# 2018-08-31 21:00:00         159    21          4      8  154.0   198.0
# 2018-08-31 22:00:00         223    22          4      8  159.0   158.0
# 2018-08-31 23:00:00         205    23          4      8  223.0   246.0
#
#                      rolling_mean_3
# datetime
# 2018-03-02 00:00:00       79.000000
# ...

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment </h2>
#
# Correct. Sometimes we can notice autocorrelation in time series. It means that the current value of the series depends on the previous values. Including so-called lag components allows machine learning models, such as linear regression, to take this dependency into account.
# </div>

# %% [markdown]
# ## Training

# %%
split_idx = int(len(df) * 0.9)
train = df.iloc[:split_idx]
test = df.iloc[split_idx:]

features = ['hour', 'dayofweek', 'month', 'lag_1', 'lag_24', 'rolling_mean_3']
target = 'num_orders'

X_train = train[features]
y_train = train[target]
X_test = test[features]
y_test = test[target]

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment </h2>
#
# Correct!
#
# </div>

# %% [markdown]
# ## Testing

# %%
# Define parameter grid for hyperparameter tuning
param_grid = {
    'n_estimators': [50, 100, 150],
    'max_depth': [5, 10, 15, None],
    'min_samples_split': [2, 5, 10]
}

# Use time series split for cross-validation
tscv = TimeSeriesSplit(n_splits=5)

# Initialize Random Forest Regressor
rf_model = RandomForestRegressor(random_state=42)

# Set up GridSearchCV
grid_search = GridSearchCV(
    estimator=rf_model,
    param_grid=param_grid,
    cv=tscv,
    scoring='neg_root_mean_squared_error',
    n_jobs=-1,
    verbose=1
)

# Fit GridSearchCV on the training set only
grid_search.fit(X_train, y_train)

# Best parameters and best score
best_params = grid_search.best_params_
best_score = -grid_search.best_score_  # convert back to positive RMSE

best_params, best_score
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# ({'max_depth': None, 'min_samples_split': 10, 'n_estimators': 150},
#  25.611449077672727)

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 2 </h2>
#
# Good!
#
# </div>
#
#
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
#
# Please do not use the test subset, use `X_train` instead. We should save the test subset for the final test in the very end of the project after we identify the best model (one model) among all models we trained and tuned. In other words, we use test subset once, in the very end.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# I have updated the training models as well as the test model's cell.  </div>

# %%
dt = DecisionTreeRegressor(
    max_depth=10,              
    min_samples_split=5,       
    random_state=42
)



#dt = DecisionTreeRegressor(random_state=42)
dt.fit(X_train, y_train)
train_preds_dt = dt.predict(X_train)

# Evaluate using RMSE on training set only
rmse_train_dt = np.sqrt(mean_squared_error(y_train, train_preds_dt))
print(f"Decision Tree Training RMSE: {rmse_train_dt:.2f}")
# Out:
# Decision Tree Training RMSE: 18.23

# %%
xgb = XGBRegressor(n_estimators=200, learning_rate=0.1, random_state=42)
xgb.fit(X_train, y_train)
train_preds_xgb = xgb.predict(X_train)


rmse_xgb = np.sqrt(mean_squared_error(y_train, train_preds_xgb))
print(f"XGBoost RMSE: {rmse_xgb:.2f}")
# Out:
# XGBoost RMSE: 11.38

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 2 </h2>
#
# Nice results!
# </div>

# %%
# Hyperparameter tuning with GridSearchCV in attempt to lower RMSE score for the final test to achieve goal of < 48
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.05, 0.1],
    'subsample': [0.7, 0.9, 1.0],
    'colsample_bytree': [0.7, 0.9, 1.0]
}

tscv = TimeSeriesSplit(n_splits=5)

xgb = XGBRegressor(random_state=42)
grid_search = GridSearchCV(
    estimator=xgb,
    param_grid=param_grid,
    cv=tscv,
    scoring='neg_root_mean_squared_error',
    verbose=1,
    n_jobs=-1
)

# Fit on training data only
grid_search.fit(X_train, y_train)

# Get best parameters and score
best_params = grid_search.best_params_
best_score = -grid_search.best_score_

best_params, best_score
# Out:
# Fitting 5 folds for each of 243 candidates, totalling 1215 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 23
#      13 grid_search = GridSearchCV(
#      14     estimator=xgb,
#      15     param_grid=param_grid,
#    (...)
#      19     n_jobs=-1
#      20 )
#      22 # Fit on training data only
# ---> 23 grid_search.fit(X_train, y_train)
#      25 # Get best parameters and score
#      26 best_params = grid_search.best_params_
#
# File /opt/conda/envs/python3/lib/python3.9/site-packages/sklearn/utils/validation.py:63, in _deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      61 extra_args = len(args) - len(all_args)
#      62 if extra_args <= 0:
# ---> 63     return f(*args, **kwargs)
#      65 # extra_args > 0
#      66 args_msg = ['{}={}'.format(name, arg)
# ...

# %%
# Evaluate best model on the test subset

test_preds_xgb = xgb.predict(X_test)
final_rmse_xgb = np.sqrt(mean_squared_error(y_test, test_preds_xgb))
print(f"XGB Test RMSE: {final_rmse_xgb:.2f}")

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 2 </h2>
#
# Excellent! I ran the project on my local machine, since it was faster.
#
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment </h2>
#
# Several models were trained, well done!
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment </h2>
#
# You can also try advanced models such as ARIMA.
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
#
# - Same issues with the two models above.
#
#
# - Please try to implement hyperparameter tuning for at least one of the models. For this purpose, we either need to split data into three subsets or use cross-validation. If you choose the second option, please do not forget about the correct order in the data. In order to use the `GridSearchCV` method correctly, we have to employ the `TimeSeriesSplit` class, a cross-validator for time series.
#
#
#
# - After you do this, please choose the best model to run the final test. In the testing section, we usually test one model that yielded the highest metric value. The test subset (usually called hold-out subset) that is saved for the final test is used for an objective evaluation of the model's quality after training and hyperparameter tuning. In real tasks, you will deal with huge models, their execution may take hours and even days in some cases. Sometimes you will just not have enough time to check each model on the test subset. So let's choose the best model and test it. You only need to make ppredictions and calculate RMSE on the test data using the best model.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# I have updated the training models as well as the test model's cell. I've also implemented hyperparameter tuning on two models one to meet requirements and one to fine tune the model in attemmpt to achieve better RMSE score for the test subset.  </div>

# %% [markdown]
# ## Project Conclusion
#
# Among all tested models, the XGB Regressor performed the best, achieving the lowest RMSE on the training set. It consistently outperformed simpler models like Decision Trees, especially when dealing with time-series data that involves both trend and seasonality.We recommend deploying the XGB model for hourly taxi demand forecasting. We then tweaked the hyperparmeters to better align our final test RMSE score to meet goal. Although the computational time takes a bit, It meets the required accuracy and is well-suited for this type of time-based data. Sweet Lift Taxi will now be able to predict the amount of orders for the next hour which will provide them the abilitiy to plan their manpower goals to accommadate all orders.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 2 </h2>
#
# Great job, thank you so much!
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment</h2>
#
#
# The conclusion is written well.
# </div>
#
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
# Don't forget to update it.
#
# </div>

# %% [markdown]
# # Review checklist

# %% [markdown]
# - [x]  Jupyter Notebook is open
# - [x]  The code is error-free
# - [x]  The cells with the code have been arranged in order of execution
# - [x]  The data has been downloaded and prepared
# - [x]  The data has been analyzed
# - [x]  The model has been trained and hyperparameters have been selected
# - [x]  The models have been evaluated. Conclusion has been provided
# - [x] *RMSE* for the test set is not more than 48
